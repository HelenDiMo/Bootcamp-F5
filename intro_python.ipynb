# %% [markdown]
# <a href="https://colab.research.google.com/github/HelenDiMo/Bootcamp-F5/blob/main/intro_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 25/03/2026

# %% [markdown]
# Introduccion a Python

# %%
print(f"Hey world!!!")
# Out:
# Hey world!!!

# %% [markdown]
# ¿Cómo saber el tipo de dato que estamos utilizando?

# %%
print(type("Hola"))
print(type("123"))
print(type(25))
print(type(-4))
print(type(10.5))
print(type(3.14))
print(type(True))
print(type(False))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>

# %%
int(input("Qué edad tienes?: "))
# Out:
# Qué edad tienes?: 34
# 34
